# %% [markdown]
# # Overview of Jupyter Notebooks and Utilities Applied to Generate Paper Plots

# %% [markdown]
# Here, we list all jupyter notebooks that have been run to plot all figures of the paper:
#
# Senf, F. and R. Cremer: **Advancing the Capabilities for Efficient Hurricane-Centric Simulations with the Atmospheric Model ICON**, *submitted to Geoscientific Model Development*.
#
# Preprint is available under ???

# %% [markdown]
# ## Project Structure

# %% [markdown]
# * The *images* are locally hosted under

# %%
# %%bash
#
# ls ../paper-pics/
# Out:
# Fig01.jpg
# Fig02.jpg
# Fig03.jpg
# Fig04.jpg
# Fig05.jpg
# Fig06.jpg
# Fig07.jpg
# Fig08.jpg
# Fig09.jpg
# Fig10.jpg
# Fig11.jpg

# %% [markdown]
# * and all *jupyter notebooks* are stored here

# %%
# %%bash
#
# ls .
# Out:
# 00-Overview.ipynb
# 01-Centric-Domains-Overview-Map.ipynb
# 02-Plot-Reflected-Solar-for-Paulette-Base-Run.ipynb
# 03-Plot-Nest-Sequence-for-Selected-Segment.ipynb
# 04-Plot-IWP-with-Centred-Hurricane-Visualizations.ipynb

# %% [markdown]
# * and utilities for schematic figures are stored here

# %%
# %%bash
#
# ls ../schemes/
# Out:
# flowchart-combiner.sh
# grid-flowchart.md
# ic-flowchart-pre.md
# ic-flowchart-prod.md
# segment-scheme.odp
# workflow-overview.odp

# %% [markdown]
# * Finally, these *model data* need to be available (Download them via [zenodo.org](zenodo.org)):
#     - name data here

# %% [markdown]
# ## Figure 1: Workflow Overview

# %% [markdown]
# ![Figure 1](../paper-pics/Fig01.jpg)
#
# **Caption:** Overview of the flexible refinement workflow: Five steps are shown in different colored boxes and numbered accordingly. The steps of the workflow include (1) creating the base simulation, (2) identifying and tracking the hurricane, (3) creating the flexible grids and other necessary simulation data, (4) combining the initial conditions from the base and newly created simulation data, and (5) performing the actual high-resolution hurricane simulation. Gray arrows indicate the flow in the workflow diagram, with steps 4 and 5 being performed as iterative loop over the respective hurricane segments.

# %% [markdown]
# 1. overview scheme was created with `../schemes/workflow-overview.odp` and
# 2. exported into a PNG file

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 2: Track Segment Schematic

# %% [markdown]
# ![Figure 2](../paper-pics/Fig02.jpg)
#
# **Caption:** Schematic representation of a track segment. The reference track is represented by a thick, dashed black line. A grid segment with a width of $\Delta s_\mathrm{width}$ is constructed around it (thin solid black line). The spatial points A to D are determined by their temporal sequence along the track. The circles around points B and C indicate the areas of interest for analysis at the start and end time of the simulation within the segment. Points A and D show the extension of the grid segment by a predefined time $\Delta t_\mathrm{add}$. For simplicity, only the outer nest of the track segment is shown. Further nests follow the same scheme, but lie inside the outer nest with smaller across-track widths.

# %% [markdown]
# 1. segment cheme was created with `../schemes/segment-scheme.odp` and
# 2. exported into a PNG file

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 3: Grid Generation Flowchart

# %% [markdown]
# ![Figure 3](../paper-pics/Fig03.jpg)
#
# **Caption:** Detailed flowchart for the sequential grid generation process. Final and intermediate start and end points are highlighted in red. Incoming and outgoing data are visualized as slanted blue boxes and methods that treat these data are shown as green rectangles.

# %% [markdown]
# - Grid flowchart was created with `../schemes/grid-flowchart.md` and translated to an image with `../schemes/flowchart-combiner.sh`

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 4: Initial Conditions Flowchart

# %% [markdown]
# ![Figure 4](../paper-pics/Fig04.jpg)
#
# **Caption:** Detailed flowchart for (a) initial conditions pre-processing and (b) initial conditions production. Final and intermediate start and end points are highlighted in red. See Fig. 3 for meaning of the different elements.

# %% [markdown]
# - IC flowcharts were created with
#   1. `../schemes/ic-flowchart-pre.md` for preparations and
#   2. `../schemes/ic-flowchart-prod.md` for productions
# - translated to an image with `../schemes/flowchart-combiner.sh`

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 5: Hurricane Paulette Overview

# %% [markdown]
# ![Figure 5](../paper-pics/Fig05.jpg)
#
# **Caption:** Top view of hurricane Paulette from (a) observations and (b) simulations. A regional cutout in the Atlantic ocean was defined to reached from -74.0 to -53.4 °E and from 25.0 to 43.2 °N. Subpanel (a) shows a true-colour image acquired by the Moderate Resolution Imaging Spectroradiometer (MODIS) instrument on the NOAA-AQUA satellite during an ascending orbit at overpass time on 14 September 2020, around 18:00 UTC. Subpanel (b) provides a simulation of the reflected solar radiation flux, normalized between 100 and 750 W m⁻² from our ICON base run, which was initialized on 7 September 2020 at 0 UTC. The time, geographical region and projection have been matched between the observation and the simulation. The color scale and map in (b) have been adjusted to ensure visual consistency with (a). The length scale of 400 km is shown in the lower right corner of (b) and the inset in the upper right corner of (b) shows the location of the cutout in the Atlantic ocean.

# %% [markdown]
# - figure is prepared in [01-Plot-Reflected-Solar-for-Paulette-Base-Run.ipynb](01-Plot-Reflected-Solar-for-Paulette-Base-Run.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 6: Grid Segments for Different Setups

# %% [markdown]
# ![Figure 6](../paper-pics/Fig06.jpg)
#
# **Caption:** Grid segments prepared for hurricane Paulette (2020) with differently chosen re-initialization times and across-track widths. The narrow setup in (a) and (b) is compared to the medium setup in (c) and (d). Re-initialization at 12-hour intervals (a, c) leads to twice as many segments as re-initialization at 24-hour intervals (see Tab. 1). The track of the hurricane Paulette in the base simulation is plotted as a white solid line. Each segment consists of three nested domains (solid lines of decreasing thickness) colored by the initialization time, ranging from red on September 8 to blue on September 14.

# %% [markdown]
# - figure is prepared in [02-Centric-Domains-Overview-Map.ipynb](02-Centric-Domains-Overview-Map.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 7: Hurricane Track and Intensity Analysis

# %% [markdown]
# ![Figure 7](../paper-pics/Fig07.jpg)
#
# **Caption:** Simulated hurricane characteristics for grid configurations with differently chosen across-track widths. (a) The minimum pressure positions are plotted on a map, with colors representing the respective grid segments. The re-initialization time between successive segments is set to 12 hours. The narrow-size setup (small, solid circle at the end of the track) is compared to the medium-size setup (larger, solid circle at the end of the track). Different resolutions are plotted with different line thicknesses, ranging from thick for R2B11 to thin for R2B13, and they partially overlap. The minimum pressure and maximum 10-m wind speed are presented using similar color and line encoding as in (b) and (c).

# %% [markdown]
# - figure is prepared in [03-Plot-Minimum-Pressure-Tracks-and-Intensity.ipynb](03-Plot-Minimum-Pressure-Tracks-and-Intensity.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 8: Variables in Different Nested Domains

# %% [markdown]
# ![Figure 8](../paper-pics/Fig08.jpg)
#
# **Caption:** An overview of various variables, shown in the respective nests for a specific grid segment. The grid configuration was chosen so that the re-initialization time is 12 hours and the nests have an across-track width of 300, 200, and 100 km, respectively (narrow-size setup). The equivalent grid spacing is indicated above the respective nest. Variables shown are (a) 2 m temperature, (b) 10 m wind speed, (c) reflected solar radiation flux at TOA and (d) total column water vapor for segment 11 at 18 UTC on 12 September 2020.

# %% [markdown]
# - figure is prepared in [04-Plot-Nest-Sequence-for-Selected-Segment.ipynb](04-Plot-Nest-Sequence-for-Selected-Segment.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 9: Lagrangian Analysis of Ice Water Path

# %% [markdown]
# ![Figure 9](../paper-pics/Fig09.jpg)
#
# **Caption:** Ice water path is shown as a sequence in a Lagrangian framework. The boldly shaded regions highlight the circular analysis area that follows the track of the reference hurricane. The remaining parts of the grid segment are indicated by very light colors. Two-hour steps are made in the temporal sequence. Discontinuous jumps between segments are visible between the first and second images, as well as between the second-to-last and last images. However, there is no discontinuity in the Lagrangian analysis region. Here, the medium-size grid configuration was chosen so that the shown nest has 500 km across-track width with re-initialization time of 12 hours.

# %% [markdown]
# - figure is prepared in [05-Plot-IWP-with-Centred-Hurricane-Visualizations.ipynb](05-Plot-IWP-with-Centred-Hurricane-Visualizations.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 10: Spin-up Temporal Evolution

# %% [markdown]
# ![Figure 10](../paper-pics/Fig10.jpg)
#
# **Caption:** Temporal evolution of the respective median values of surface and integrated cloud variables evaluated in the circular Lagrangian analysis region. The respective colored curves show the development of (a) surface pressure, (b) 2 m temperature, (c) 2 m specific humidity, (d) total column water vapor, (e) liquid water path, and (f) ice water path for the grid segments of the medium setup with 12h-reinit. For all curves, the anomaly relative to the respective values at the segment init is shown. The gray vertical lines mark zero and two hours (thin dashed) and 0.5 hours (thick solid) after init, which are used for subsequent analyses.

# %% [markdown]
# - figure is prepared in [06-Plot-Percentile-TSeries.ipynb](06-Plot-Percentile-TSeries.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## Figure 11: Statistical Analysis of Spin-up Effects

# %% [markdown]
# ![Figure 11](../paper-pics/Fig11.jpg)
#
# **Caption:** Statistical summary of potential spin-up effects. For the time of 0.5 hours after the respective init, nine different percentiles in the range between 10 and 90% (in steps of 10%) were calculated in the Lagrangian analysis region and converted into anomalies relative to a reference value. The reference value was chosen as the average between the values at times 0 and 2 hours. All values obtained in this way were statistically summarized as probability density functions and plotted as colored bars stacked on top of each other for each segment. The six rows show the respective setups, with the narrow and medium setups shown for re-initialization periods of 12h and 24h, respectively. The columns show surface pressure, 2 m temperature, liquid water path, and ice water path. The spin-up analyses are only shown for the outer nest with a grid spacing of approximately 1 km.

# %% [markdown]
# - figure is prepared in [07-Explore-Percentile-BarStats-for-all-Exp.ipynb](07-Explore-Percentile-BarStats-for-all-Exp.ipynb)
